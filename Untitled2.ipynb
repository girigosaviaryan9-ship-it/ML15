# %% [markdown]
# <a href="https://colab.research.google.com/github/girigosaviaryan9-ship-it/ML15/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load dataset
data = pd.read_csv("data.csv")

# Input (X) and Output (Y)
X = data[["X"]]
y = data["Y"]

# Create Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Predict values
y_pred = model.predict(X)

# Print coefficients
print("Intercept (b0):", model.intercept_)
print("Slope (b1):", model.coef_[0])

# Plot original data
plt.scatter(X, y, label="Actual Data")

# Plot regression line
plt.plot(X, y_pred, label="Regression Line")

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression using Scikit-learn")
plt.legend()

plt.show()
# Out:
# Intercept (b0): -0.6415999688364931
# Slope (b1): 2.067875700585989
