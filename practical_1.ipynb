# %% [markdown]
# <a href="https://colab.research.google.com/github/girigosaviaryan9-ship-it/ML15/blob/main/practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("SURAJ")
# Out:
# SURAJ
